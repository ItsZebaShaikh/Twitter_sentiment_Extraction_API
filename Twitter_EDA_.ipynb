# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from plotly import graph_objs as go #Used To Create Publish Quality Graphs
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator #Used To Create Wordcloud
from PIL import Image

import nltk #used for statistical natural language processing (NLP)
from nltk.corpus import stopwords #used for stopword processing

from tqdm import tqdm #Used As a support for nested loops
import os
import nltk
import spacy #statistical model for NER
import random
from spacy.util import compounding
from spacy.util import minibatch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing Dataset using pandas
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/test.csv')
ss = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sample_submission.csv')

# %%
print(train.shape)
print(test.shape)
# Out:
# (27481, 4)
# (3534, 3)

# %% [markdown]
# __So We have 27481 tweets in the train set and 3534 tweets in the test set.__

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27481 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27481 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27481 non-null  object
# dtypes: object(4)
# memory usage: 858.9+ KB

# %%
train.isna().sum()
# Out:
# textID           0
# text             1
# selected_text    1
# sentiment        0
# dtype: int64

# %% [markdown]
# __We have one null Value in the train , as the test field for value is NAN we will just remove it.__

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27481 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27481 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27481 non-null  object
# dtypes: object(4)
# memory usage: 858.9+ KB

# %%
train.dropna(inplace=True)

# %%
train.isna().sum()
# Out:
# textID           0
# text             0
# selected_text    0
# sentiment        0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27480 entries, 0 to 27480
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   textID         27480 non-null  object
#  1   text           27480 non-null  object
#  2   selected_text  27480 non-null  object
#  3   sentiment      27480 non-null  object
# dtypes: object(4)
# memory usage: 1.0+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3534 entries, 0 to 3533
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   textID     3534 non-null   object
#  1   text       3534 non-null   object
#  2   sentiment  3534 non-null   object
# dtypes: object(3)
# memory usage: 83.0+ KB

# %%
test.isna().sum()
# Out:
# textID       0
# text         0
# sentiment    0
# dtype: int64

# %% [markdown]
# __There are no null Values in the test set.__

# %% [markdown]
# __EDA__

# %%
train.head()
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]

# %% [markdown]
# __Here, Selected_text is a subset of text.__

# %%
train.describe()
# Out:
#             textID  ... sentiment
# count        27480  ...     27480
# unique       27480  ...         3
# top     23013f9a40  ...   neutral
# freq             1  ...     11117
#
# [4 rows x 4 columns]

# %%
temp = train.groupby('sentiment').count()['text'].reset_index().sort_values(by='text',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
# #T_91d6ae50_b1c2_11eb_985c_0242ac1c0002row0_col1{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_91d6ae50_b1c2_11eb_985c_0242ac1c0002row1_col1{
#             background-color:  #dcdcec;
#             color:  #000000;
#         }#T_91d6ae50_b1c2_11eb_985c_0242ac1c0002row2_col1{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_91d6ae50_b1c2_11eb_985c_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sentiment</th>        <th class="col_heading level0 col1" >text</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_91d6ae50_b1c2_11eb_985c_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_91d6ae50_b1c2_11eb_985c_0242ac1c0002row0_col0" class="data row0 col0" >neutral</td>
# ...

# %%
#Lets look at the distribution of tweets in the train set
plt.figure(figsize=(12,6))
sns.countplot(x='sentiment',data=train)

# %% [markdown]
# __Let's draw a Funnel-Chart for better visualization.__

# %%
fig = go.Figure(go.Funnelarea(
    text =temp.sentiment,
    values = temp.text,
    title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a38bce0c-05a9-4719-bf86-8f3682fd4dd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a38bce0c-05a9-4719-bf86-8f3682fd4dd2")) {
#                     Plotly.newPlot(
#                         'a38bce0c-05a9-4719-bf86-8f3682fd4dd2',
# ...

# %% [markdown]
# What do we currently Know About our Data:
# Before starting let's look at some things that we already know about the data and will help us in gaining more new insights:
#
# We Know that selected_text is a subset of text
# We know that selected_text contains only one segment of text,i.e,It does not jump between two sentences.
# For Eg:- If text is 'Spent the entire morning in a meeting w/ a vendor, and my boss was not happy w/ them.
#
# Lots of fun.
# I had other plans for my morning' The selected text can be 'my boss was not happy w/ them.
#
# Lots of fun' or 'Lots of fun' but cannot be 'Morning,vendor and my boss,
#
# We are not sure that preprocessing and removing punctuations would be a good idea or not.

# %% [markdown]
# __Jaccard Similarity Scores between text and Selected_text__

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c)) #using Jaccard Index Formulae

# %%
results_jaccard=[]

for ind,row in train.iterrows():
    sentence1 = row.text
    sentence2 = row.selected_text

    jaccard_score = jaccard(sentence1,sentence2)
    results_jaccard.append([sentence1,sentence2,jaccard_score])

# %%
jaccard = pd.DataFrame(results_jaccard,columns=["text","selected_text","jaccard_score"])
train = train.merge(jaccard,how='outer')

# %%
train['Num_words_ST'] = train['selected_text'].apply(lambda x:len(str(x).split())) #Number Of words in Selected Text
train['Num_word_text'] = train['text'].apply(lambda x:len(str(x).split())) #Number Of words in main text
train['difference_in_words'] = train['Num_word_text'] - train['Num_words_ST'] #Difference in Number of words text and Selected Text

# %%
train.head(8)
# Out:
#        textID  ... difference_in_words
# 0  cb774db0d1  ...                   0
# 1  549e992a42  ...                   8
# 2  088c60f138  ...                   3
# 3  9642c003ef  ...                   2
# 4  358bd9e861  ...                  11
# 5  28b57f3990  ...                   0
# 6  6e0c6d75b1  ...                  13
# 7  50e14c0bb8  ...                   0
#
# [8 rows x 8 columns]

# %% [markdown]
# __Let's look at the distribution of Meta-Features.__

# %%
hist_data = [train['Num_words_ST'],train['Num_word_text']]

group_labels = ['Selected_Text', 'Text']

# Create distplot with custom bin_size
fig = ff.create_distplot(hist_data, group_labels,show_curve=False)
fig.update_layout(title_text='Distribution of Number Of words')
fig.update_layout(
    autosize=False,
    width=900,
    height=700,
    paper_bgcolor="LightSteelBlue",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="093e6b3a-896c-4696-b4e3-9aeb0b9ec1eb" class="plotly-graph-div" style="height:700px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("093e6b3a-896c-4696-b4e3-9aeb0b9ec1eb")) {
#                     Plotly.newPlot(
#                         '093e6b3a-896c-4696-b4e3-9aeb0b9ec1eb',
# ...

# %% [markdown]
# The number of words plot is really interesting ,the tweets having number of words greater than 25 are very less and thus the number of words distribution plot is right skewed.

# %%
k = train[train['Num_word_text']<=2]

# %%
k.groupby('sentiment').mean()['jaccard_score']
# Out:
# sentiment
# negative    0.788580
# neutral     0.977805
# positive    0.765700
# Name: jaccard_score, dtype: float64

# %%
k[k['sentiment']=='positive']
# Out:
#            textID  ... difference_in_words
# 68     fa2654e730  ...                   0
# 80     bbbc46889b  ...                   0
# 170    f3d95b57b1  ...                   0
# 278    89d5b3f0b5  ...                   0
# 429    a78ef3e0d0  ...                   0
# ...           ...  ...                 ...
# 26689  e80c242d6a  ...                   0
# 26725  aad244f37d  ...                   0
# 26842  a46571fe12  ...                   0
# 26959  49a942e9b1  ...                   0
# 27292  47c474aaf1  ...                   1
#
# [207 rows x 8 columns]

# %% [markdown]
# Thus its clear that most of the times , text is used as selected text.
#
# We can improve this by preprocessing the text which have word length less than 3.
# We will remember this information and use it in model building

# %% [markdown]
# __Cleaning the Corpus:__
#
# Now Before We Dive into extracting information out of words in text and selected text,let's first clean the data.

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+http://', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
train['text'] = train['text'].apply(lambda x:clean_text(x))
train['selected_text'] = train['selected_text'].apply(lambda x:clean_text(x))

# %%
train.head()
# Out:
#        textID  ... difference_in_words
# 0  cb774db0d1  ...                   0
# 1  549e992a42  ...                   8
# 2  088c60f138  ...                   3
# 3  9642c003ef  ...                   2
# 4  358bd9e861  ...                  11
#
# [5 rows x 8 columns]

# %% [markdown]
# __Finding Most Common words in our Target-Selected Text__

# %%
train['temp_list'] = train['selected_text'].apply(lambda x:str(x).split()) #Creates a Gradient list
top = Counter([item for sublist in train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_df4155bc_c82c_11ea_b529_0242ac1c0002row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_df4155bc_c82c_11ea_b529_0242ac1c0002row1_col1 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_df4155bc_c82c_11ea_b529_0242ac1c0002row2_col1 {
#             background-color:  #57a0ce;
#             color:  #000000;
#         }    #T_df4155bc_c82c_11ea_b529_0242ac1c0002row3_col1 {
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }    #T_df4155bc_c82c_11ea_b529_0242ac1c0002row4_col1 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_df4155bc_c82c_11ea_b529_0242ac1c0002row5_col1 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_df4155bc_c82c_11ea_b529_0242ac1c0002row6_col1 {
#             background-color:  #d3e4f3;
#             color:  #000000;
# ...

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="68d3fc64-69f1-4464-bd61-90581e896350" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("68d3fc64-69f1-4464-bd61-90581e896350")) {
#                     Plotly.newPlot(
#                         '68d3fc64-69f1-4464-bd61-90581e896350',
# ...

# %% [markdown]
# While we cleaned our dataset we didnt remove the stop words and hence we can see the most coomon word is 'to' .
# Let's try again after removing the stopwords.

# %%
#import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
train['temp_list'] = train['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_0913be66_c82d_11ea_b529_0242ac1c0002row0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_0913be66_c82d_11ea_b529_0242ac1c0002row1_col1 {
#             background-color:  #6c55a5;
#             color:  #f1f1f1;
#         }    #T_0913be66_c82d_11ea_b529_0242ac1c0002row2_col1 {
#             background-color:  #9692c4;
#             color:  #000000;
#         }    #T_0913be66_c82d_11ea_b529_0242ac1c0002row3_col1 {
#             background-color:  #a9a7cf;
#             color:  #000000;
#         }    #T_0913be66_c82d_11ea_b529_0242ac1c0002row4_col1 {
#             background-color:  #c2c3df;
#             color:  #000000;
#         }    #T_0913be66_c82d_11ea_b529_0242ac1c0002row5_col1 {
#             background-color:  #c3c4e0;
#             color:  #000000;
#         }    #T_0913be66_c82d_11ea_b529_0242ac1c0002row6_col1 {
#             background-color:  #c5c6e1;
#             color:  #000000;
# ...

# %%
train['temp_list1'] = train['text'].apply(lambda x:str(x).split()) #List of words in every row for text
train['temp_list1'] = train['temp_list1'].apply(lambda x:remove_stopword(x)) #Removing Stopwords

# %% [markdown]
# __Finding Most Common words in Text:__
#
# Let's also look at the most common words in Text

# %%
top = Counter([item for sublist in train['temp_list1'] for item in sublist])
temp = pd.DataFrame(top.most_common(25))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row1_col1 {
#             background-color:  #4292c6;
#             color:  #000000;
#         }    #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row2_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row3_col1 {
#             background-color:  #79b5d9;
#             color:  #000000;
#         }    #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row4_col1 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row5_col1 {
#             background-color:  #a5cde3;
#             color:  #000000;
#         }    #T_1d542dc0_c82d_11ea_b529_0242ac1c0002row6_col1 {
#             background-color:  #b8d5ea;
#             color:  #000000;
# ...

# %%
raw_text = [word for word_list in train['temp_list1'] for word in word_list]

# %% [markdown]
# We can see words like get,go,dont,got,u,cant,lol,like are common in all three segments .
#
# That's interesting because words like dont and cant are more of negative nature and words like lol are more of positive nature.
#
# It will be interesting to see the word unique to different sentiments.

# %% [markdown]
# __Finding Unique Words in each Segment:__

# %%
def words_unique(sentiment,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result; 
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in train[train.sentiment != sentiment]['temp_list1']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in raw_text if x not in allother]
    
    mycounter = Counter()
    
    for item in train[train.sentiment == sentiment]['temp_list1']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
    return Unique_words

# %%
Unique_Positive= words_unique('positive', 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_Positive.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style  type="text/css" >
#     #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row1_col1 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row2_col1 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row3_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row4_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row5_col1 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_3f220ab2_c82d_11ea_b529_0242ac1c0002row6_col1 {
# ...

# %%
Unique_Neutral= words_unique('neutral', 10, raw_text)
print("The top 10 unique words in Neutral Tweets are:")
Unique_Neutral.style.background_gradient(cmap='Oranges')
# Out:
# The top 10 unique words in Neutral Tweets are:
# <style  type="text/css" >
#     #T_568a8396_c82d_11ea_b529_0242ac1c0002row0_col1 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_568a8396_c82d_11ea_b529_0242ac1c0002row1_col1 {
#             background-color:  #fd8c3b;
#             color:  #000000;
#         }    #T_568a8396_c82d_11ea_b529_0242ac1c0002row2_col1 {
#             background-color:  #fdd0a2;
#             color:  #000000;
#         }    #T_568a8396_c82d_11ea_b529_0242ac1c0002row3_col1 {
#             background-color:  #fdd0a2;
#             color:  #000000;
#         }    #T_568a8396_c82d_11ea_b529_0242ac1c0002row4_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_568a8396_c82d_11ea_b529_0242ac1c0002row5_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_568a8396_c82d_11ea_b529_0242ac1c0002row6_col1 {
# ...

# %% [markdown]
# ___By Looking at the Unique Words of each sentiment, we now have much more clarity about the data,
# these unique words are very strong determiners of Sentiment of tweets___

# %% [markdown]
# __WordClouds:__
#
# We will be building wordclouds in the following order:
#
# 1) WordCloud of Neutral Tweets
#
# 2) WordCloud of Positive Tweets
#
# 3)WordCloud of Negative Tweets

# %%
Positive_sent = train[train['sentiment']=='positive']
Negative_sent = train[train['sentiment']=='negative']
Neutral_sent = train[train['sentiment']=='neutral']

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0), color = 'white',
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'u', "im"}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color=color,
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    width=400, 
                    height=200,
                    mask = mask)
    wordcloud.generate(str(text))
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()

# %%
pos_mask = np.array(Image.open('/content/drive/My Drive/TweetsData/download.png'))
plot_wordcloud(Neutral_sent.text,mask=pos_mask,color='white',max_font_size=50,title_size=30,title="WordCloud of Neutral Tweets")

# %%
plot_wordcloud(Positive_sent.text,mask=pos_mask,title="Word Cloud Of Positive tweets",title_size=30)

# %%
plot_wordcloud(Negative_sent.text,mask=pos_mask,title="Word Cloud of Negative Tweets",color='white',title_size=30)
